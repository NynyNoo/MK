# %%
#Matematyka Konkretna

# %%
#Laboratorium 8

# %%
#Szymon Białek https://github.com/NynyNoo/MK

# %%
#Wariant 11

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

def generate_data_mean(num_samples, seq_length):
    X = np.random.choice([0, 0.2, 0.4, 0.6, 0.8, 1], size=(num_samples, seq_length, 1))
    y = np.mean(X, axis=1)
    return X, y

num_samples = 30
seq_length = 20
input_dim = 1
output_dim = 1

X_train, y_train = generate_data_mean(num_samples, seq_length)

model = Sequential()
model.add(SimpleRNN(units=10, input_shape=(seq_length, input_dim)))
model.add(Dense(units=output_dim, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])  # Używam średniego błędu bezwzględnego (mae) jako metryki.

model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

X_test, y_test = generate_data_mean(5, seq_length)
predictions = model.predict(X_test)

for i in range(len(X_test)):
    print("Input:", X_test[i].flatten())
    print("True Output:", y_test[i])
    print("Predicted Output:", predictions[i][0])
    print("\n")

# %% [raw]
# 30/30 - 1s - loss: 0.6794 - mae: 0.6806 - 1s/epoch - 36ms/step
# Epoch 2/100
# 30/30 - 0s - loss: 0.1207 - mae: 0.2847 - 62ms/epoch - 2ms/step
# Epoch 3/100
# 30/30 - 0s - loss: 0.1083 - mae: 0.2637 - 60ms/epoch - 2ms/step
# Epoch 4/100
# 30/30 - 0s - loss: 0.0908 - mae: 0.2382 - 65ms/epoch - 2ms/step
# Epoch 5/100
# 30/30 - 0s - loss: 0.0716 - mae: 0.2176 - 59ms/epoch - 2ms/step
# Epoch 6/100
# 30/30 - 0s - loss: 0.0651 - mae: 0.2085 - 58ms/epoch - 2ms/step
# Epoch 7/100
# 30/30 - 0s - loss: 0.0542 - mae: 0.1812 - 57ms/epoch - 2ms/step
# Epoch 8/100
# 30/30 - 0s - loss: 0.0443 - mae: 0.1729 - 58ms/epoch - 2ms/step
# Epoch 9/100
# 30/30 - 0s - loss: 0.0404 - mae: 0.1672 - 63ms/epoch - 2ms/step
# Epoch 10/100
# 30/30 - 0s - loss: 0.0389 - mae: 0.1666 - 56ms/epoch - 2ms/step
# Epoch 11/100
# 30/30 - 0s - loss: 0.0387 - mae: 0.1683 - 64ms/epoch - 2ms/step
# Epoch 12/100
# 30/30 - 0s - loss: 0.0283 - mae: 0.1400 - 56ms/epoch - 2ms/step
# Epoch 13/100
# 30/30 - 0s - loss: 0.0247 - mae: 0.1245 - 62ms/epoch - 2ms/step
# Epoch 14/100
# 30/30 - 0s - loss: 0.0242 - mae: 0.1281 - 59ms/epoch - 2ms/step
# Epoch 15/100
# 30/30 - 0s - loss: 0.0198 - mae: 0.1175 - 68ms/epoch - 2ms/step
# Epoch 16/100
# 30/30 - 0s - loss: 0.0173 - mae: 0.1099 - 80ms/epoch - 3ms/step
# Epoch 17/100
# 30/30 - 0s - loss: 0.0157 - mae: 0.1058 - 75ms/epoch - 3ms/step
# Epoch 18/100
# 30/30 - 0s - loss: 0.0141 - mae: 0.0998 - 72ms/epoch - 2ms/step
# Epoch 19/100
# 30/30 - 0s - loss: 0.0127 - mae: 0.0958 - 73ms/epoch - 2ms/step
# Epoch 20/100
# 30/30 - 0s - loss: 0.0116 - mae: 0.0920 - 84ms/epoch - 3ms/step
# Epoch 21/100
# 30/30 - 0s - loss: 0.0105 - mae: 0.0893 - 76ms/epoch - 3ms/step
# Epoch 22/100
# 30/30 - 0s - loss: 0.0099 - mae: 0.0818 - 83ms/epoch - 3ms/step
# Epoch 23/100
# 30/30 - 0s - loss: 0.0087 - mae: 0.0818 - 71ms/epoch - 2ms/step
# Epoch 24/100
# 30/30 - 0s - loss: 0.0084 - mae: 0.0771 - 76ms/epoch - 3ms/step
# Epoch 25/100
# 30/30 - 0s - loss: 0.0085 - mae: 0.0811 - 74ms/epoch - 2ms/step
# Epoch 26/100
# 30/30 - 0s - loss: 0.0073 - mae: 0.0722 - 78ms/epoch - 3ms/step
# Epoch 27/100
# 30/30 - 0s - loss: 0.0072 - mae: 0.0733 - 75ms/epoch - 3ms/step
# Epoch 28/100
# 30/30 - 0s - loss: 0.0070 - mae: 0.0710 - 72ms/epoch - 2ms/step
# Epoch 29/100
# 30/30 - 0s - loss: 0.0066 - mae: 0.0700 - 84ms/epoch - 3ms/step
# Epoch 30/100
# 30/30 - 0s - loss: 0.0072 - mae: 0.0713 - 94ms/epoch - 3ms/step
# Epoch 31/100
# 30/30 - 0s - loss: 0.0065 - mae: 0.0624 - 91ms/epoch - 3ms/step
# Epoch 32/100
# 30/30 - 0s - loss: 0.0069 - mae: 0.0709 - 87ms/epoch - 3ms/step
# Epoch 33/100
# 30/30 - 0s - loss: 0.0058 - mae: 0.0660 - 79ms/epoch - 3ms/step
# Epoch 34/100
# 30/30 - 0s - loss: 0.0062 - mae: 0.0637 - 83ms/epoch - 3ms/step
# Epoch 35/100
# 30/30 - 0s - loss: 0.0054 - mae: 0.0620 - 80ms/epoch - 3ms/step
# Epoch 36/100
# 30/30 - 0s - loss: 0.0057 - mae: 0.0658 - 73ms/epoch - 2ms/step
# Epoch 37/100
# 30/30 - 0s - loss: 0.0059 - mae: 0.0627 - 75ms/epoch - 2ms/step
# Epoch 38/100
# 30/30 - 0s - loss: 0.0056 - mae: 0.0636 - 72ms/epoch - 2ms/step
# Epoch 39/100
# 30/30 - 0s - loss: 0.0053 - mae: 0.0612 - 76ms/epoch - 3ms/step
# Epoch 40/100
# 30/30 - 0s - loss: 0.0051 - mae: 0.0599 - 69ms/epoch - 2ms/step
# Epoch 41/100
# 30/30 - 0s - loss: 0.0047 - mae: 0.0584 - 74ms/epoch - 2ms/step
# Epoch 42/100
# 30/30 - 0s - loss: 0.0048 - mae: 0.0564 - 80ms/epoch - 3ms/step
# Epoch 43/100
# 30/30 - 0s - loss: 0.0048 - mae: 0.0574 - 74ms/epoch - 2ms/step
# Epoch 44/100
# 30/30 - 0s - loss: 0.0045 - mae: 0.0562 - 76ms/epoch - 3ms/step
# Epoch 45/100
# 30/30 - 0s - loss: 0.0053 - mae: 0.0567 - 72ms/epoch - 2ms/step
# Epoch 46/100
# 30/30 - 0s - loss: 0.0045 - mae: 0.0578 - 81ms/epoch - 3ms/step
# Epoch 47/100
# 30/30 - 0s - loss: 0.0046 - mae: 0.0589 - 79ms/epoch - 3ms/step
# Epoch 48/100
# 30/30 - 0s - loss: 0.0045 - mae: 0.0590 - 71ms/epoch - 2ms/step
# Epoch 49/100
# 30/30 - 0s - loss: 0.0047 - mae: 0.0583 - 73ms/epoch - 2ms/step
# Epoch 50/100
# 30/30 - 0s - loss: 0.0048 - mae: 0.0616 - 72ms/epoch - 2ms/step
# Epoch 51/100
# 30/30 - 0s - loss: 0.0042 - mae: 0.0534 - 73ms/epoch - 2ms/step
# Epoch 52/100
# 30/30 - 0s - loss: 0.0049 - mae: 0.0586 - 70ms/epoch - 2ms/step
# Epoch 53/100
# 30/30 - 0s - loss: 0.0044 - mae: 0.0561 - 68ms/epoch - 2ms/step
# Epoch 54/100
# 30/30 - 0s - loss: 0.0043 - mae: 0.0556 - 77ms/epoch - 3ms/step
# Epoch 55/100
# 30/30 - 0s - loss: 0.0044 - mae: 0.0575 - 81ms/epoch - 3ms/step
# Epoch 56/100
# 30/30 - 0s - loss: 0.0053 - mae: 0.0651 - 71ms/epoch - 2ms/step
# Epoch 57/100
# 30/30 - 0s - loss: 0.0055 - mae: 0.0628 - 75ms/epoch - 2ms/step
# Epoch 58/100
# 30/30 - 0s - loss: 0.0041 - mae: 0.0556 - 75ms/epoch - 2ms/step
# Epoch 59/100
# 30/30 - 0s - loss: 0.0040 - mae: 0.0532 - 72ms/epoch - 2ms/step
# Epoch 60/100
# 30/30 - 0s - loss: 0.0047 - mae: 0.0603 - 70ms/epoch - 2ms/step
# Epoch 61/100
# 30/30 - 0s - loss: 0.0042 - mae: 0.0561 - 70ms/epoch - 2ms/step
# Epoch 62/100
# 30/30 - 0s - loss: 0.0039 - mae: 0.0532 - 74ms/epoch - 2ms/step
# Epoch 63/100
# 30/30 - 0s - loss: 0.0041 - mae: 0.0537 - 67ms/epoch - 2ms/step
# Epoch 64/100
# 30/30 - 0s - loss: 0.0041 - mae: 0.0540 - 75ms/epoch - 2ms/step
# Epoch 65/100
# 30/30 - 0s - loss: 0.0047 - mae: 0.0568 - 81ms/epoch - 3ms/step
# Epoch 66/100
# 30/30 - 0s - loss: 0.0051 - mae: 0.0563 - 92ms/epoch - 3ms/step
# Epoch 67/100
# 30/30 - 0s - loss: 0.0057 - mae: 0.0648 - 80ms/epoch - 3ms/step
# Epoch 68/100
# 30/30 - 0s - loss: 0.0063 - mae: 0.0684 - 71ms/epoch - 2ms/step
# Epoch 69/100
# 30/30 - 0s - loss: 0.0046 - mae: 0.0581 - 73ms/epoch - 2ms/step
# Epoch 70/100
# 30/30 - 0s - loss: 0.0045 - mae: 0.0556 - 76ms/epoch - 3ms/step
# Epoch 71/100
# 30/30 - 0s - loss: 0.0037 - mae: 0.0512 - 78ms/epoch - 3ms/step
# Epoch 72/100
# 30/30 - 0s - loss: 0.0040 - mae: 0.0551 - 78ms/epoch - 3ms/step
# Epoch 73/100
# 30/30 - 0s - loss: 0.0044 - mae: 0.0522 - 77ms/epoch - 3ms/step
# Epoch 74/100
# 30/30 - 0s - loss: 0.0036 - mae: 0.0485 - 80ms/epoch - 3ms/step
# Epoch 75/100
# 30/30 - 0s - loss: 0.0041 - mae: 0.0520 - 84ms/epoch - 3ms/step
# Epoch 76/100
# 30/30 - 0s - loss: 0.0039 - mae: 0.0540 - 80ms/epoch - 3ms/step
# Epoch 77/100
# 30/30 - 0s - loss: 0.0040 - mae: 0.0524 - 82ms/epoch - 3ms/step
# Epoch 78/100
# 30/30 - 0s - loss: 0.0046 - mae: 0.0540 - 75ms/epoch - 3ms/step
# Epoch 79/100
# 30/30 - 0s - loss: 0.0042 - mae: 0.0533 - 78ms/epoch - 3ms/step
# Epoch 80/100
# 30/30 - 0s - loss: 0.0040 - mae: 0.0505 - 76ms/epoch - 3ms/step
# Epoch 81/100
# 30/30 - 0s - loss: 0.0048 - mae: 0.0598 - 77ms/epoch - 3ms/step
# Epoch 82/100
# 30/30 - 0s - loss: 0.0040 - mae: 0.0498 - 75ms/epoch - 2ms/step
# Epoch 83/100
# 30/30 - 0s - loss: 0.0041 - mae: 0.0535 - 81ms/epoch - 3ms/step
# Epoch 84/100
# 30/30 - 0s - loss: 0.0035 - mae: 0.0496 - 81ms/epoch - 3ms/step
# Epoch 85/100
# 30/30 - 0s - loss: 0.0038 - mae: 0.0495 - 79ms/epoch - 3ms/step
# Epoch 86/100
# 30/30 - 0s - loss: 0.0043 - mae: 0.0549 - 81ms/epoch - 3ms/step
# Epoch 87/100
# 30/30 - 0s - loss: 0.0037 - mae: 0.0507 - 73ms/epoch - 2ms/step
# Epoch 88/100
# 30/30 - 0s - loss: 0.0038 - mae: 0.0531 - 80ms/epoch - 3ms/step
# Epoch 89/100
# 30/30 - 0s - loss: 0.0040 - mae: 0.0518 - 74ms/epoch - 2ms/step
# Epoch 90/100
# 30/30 - 0s - loss: 0.0042 - mae: 0.0545 - 69ms/epoch - 2ms/step
# Epoch 91/100
# 30/30 - 0s - loss: 0.0038 - mae: 0.0518 - 79ms/epoch - 3ms/step
# Epoch 92/100
# 30/30 - 0s - loss: 0.0034 - mae: 0.0502 - 77ms/epoch - 3ms/step
# Epoch 93/100
# 30/30 - 0s - loss: 0.0035 - mae: 0.0502 - 77ms/epoch - 3ms/step
# Epoch 94/100
# 30/30 - 0s - loss: 0.0030 - mae: 0.0435 - 81ms/epoch - 3ms/step
# Epoch 95/100
# 30/30 - 0s - loss: 0.0041 - mae: 0.0536 - 79ms/epoch - 3ms/step
# Epoch 96/100
# 30/30 - 0s - loss: 0.0036 - mae: 0.0496 - 74ms/epoch - 2ms/step
# Epoch 97/100
# 30/30 - 0s - loss: 0.0033 - mae: 0.0476 - 79ms/epoch - 3ms/step
# Epoch 98/100
# 30/30 - 0s - loss: 0.0038 - mae: 0.0511 - 75ms/epoch - 2ms/step
# Epoch 99/100
# 30/30 - 0s - loss: 0.0040 - mae: 0.0530 - 75ms/epoch - 2ms/step
# Epoch 100/100
# 30/30 - 0s - loss: 0.0036 - mae: 0.0531 - 60ms/epoch - 2ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 240ms/step
# Input: [0.4 0.  0.  0.2 0.6 0.2 0.6 0.  0.  0.4 0.  0.  0.2 1.  0.6 1.  0.2 0.6
#  0.  0.6]
# True Output: [0.33]
# Predicted Output: 0.44927937
#
#
# Input: [0.8 0.6 1.  0.2 1.  0.  0.4 0.8 0.2 0.2 1.  0.  0.8 0.8 0.6 0.8 0.4 0.
#  0.4 1. ]
# True Output: [0.55]
# Predicted Output: 0.48623922
#
#
# Input: [0.8 0.4 0.8 0.  0.  0.8 1.  0.4 0.2 0.6 0.4 1.  0.4 0.6 0.  0.6 0.4 0.6
#  0.  0.2]
# True Output: [0.46]
# Predicted Output: 0.42517358
#
#
# Input: [0.4 0.4 0.2 0.8 0.8 1.  0.4 0.  1.  0.6 0.8 0.4 0.  0.2 0.6 0.  0.4 0.8
#  0.2 0.4]
# True Output: [0.47]
# Predicted Output: 0.43777132
#
#
# Input: [0.6 0.  0.2 0.4 0.8 0.4 0.  0.6 0.8 0.4 1.  0.8 0.4 1.  0.  1.  1.  0.6
#  0.  0.8]
# True Output: [0.54]
# Predicted Output: 0.5507662
